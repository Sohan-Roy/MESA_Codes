# %% [markdown]
# ## Period vs Pulsation Cycle

# %%
# Input Parameters : 
# Mass = 5.4
# Lunimosity = 2238.72
# Effective Temperature = 5800
# X = 0.746
# Z = 0.004


import matplotlib.pyplot as plt
import mesa_reader as mr

h=mr.MesaData('/mnt/sda1/mesa-r24.03.1/star/test_suite/rsp_Cepheid_5/LOGS/history.data')
plt.plot(h.num_periods,h.period)
plt.xlabel("Pulsation Cycle")
plt.ylabel("Period")
plt.title("Period vs Pulsation Cycle (5-days)")
plt.show()

# %%
# Input Parameters : 
# Mass = 5.1
# Lunimosity = 3006.08
# Effective Temperature = 5396
# X = 0.7
# Z = 0.02



import matplotlib.pyplot as plt
import mesa_reader as mr

h=mr.MesaData('/mnt/sda1/mesa-r24.03.1/star/test_suite/rsp_Cepheid_10/LOGS/history.data')
plt.plot(h.num_periods,h.period)
plt.xlabel("Pulsation Cycle")
plt.ylabel("Period")
plt.title("Period vs Pulsation Cycle (10-days)")
plt.show()

# %%
# Input Parameters : 
# Mass = 7.7
# Lunimosity = 4965.92
# Effective Temperature = 5332
# X = 0.7
# Z = 0.02



import matplotlib.pyplot as plt
import mesa_reader as mr

h=mr.MesaData('/mnt/sda1/mesa-r24.03.1/star/test_suite/rsp_Cepheid_12/LOGS/history.data')
plt.plot(h.num_periods,h.period)
plt.xlabel("Pulsation Cycle")
plt.ylabel("Period")
plt.title("Period vs Pulsation Cycle (12-days)")
plt.show()

# %% [markdown]
# ## Delta_R vs Pulsation Cycle

# %%
# Input Parameters : 
# Mass = 5.4
# Lunimosity = 2238.72
# Effective Temperature = 5800
# X = 0.746
# Z = 0.004


import matplotlib.pyplot as plt
import mesa_reader as mr

h=mr.MesaData('/mnt/sda1/mesa-r24.03.1/star/test_suite/rsp_Cepheid_5/LOGS/history.data')
plt.plot(h.num_periods,h.delta_R)
plt.xlabel("Pulsation Cycle")
plt.ylabel("Delta_r")
plt.title("Delta_R vs Pulsation Cycle (5-days)")
plt.show()

# %%
# Input Parameters : 
# Mass = 5.1
# Lunimosity = 3006.08
# Effective Temperature = 5396
# X = 0.7
# Z = 0.02




import matplotlib.pyplot as plt
import mesa_reader as mr

h=mr.MesaData('/mnt/sda1/mesa-r24.03.1/star/test_suite/rsp_Cepheid_10/LOGS/history.data')
plt.plot(h.num_periods,h.delta_R)
plt.xlabel("Pulsation Cycle")
plt.ylabel("Delta_r")
plt.title("Delta_R vs Pulsation Cycle (10-days)")
plt.show()

# %%
# Input Parameters : 
# Mass = 7.7
# Lunimosity = 4965.92
# Effective Temperature = 5332
# X = 0.7
# Z = 0.02


import matplotlib.pyplot as plt
import mesa_reader as mr

h=mr.MesaData('/mnt/sda1/mesa-r24.03.1/star/test_suite/rsp_Cepheid_12/LOGS/history.data')
plt.plot(h.num_periods,h.delta_R)
plt.xlabel("Pulsation Cycle")
plt.ylabel("Delta_r")
plt.title("Delta_R vs Pulsation Cycle (12-days)")
plt.show()

# %% [markdown]
# ## Growth vs Pulsation Cycle

# %%
# Input Parameters : 
# Mass = 5.4
# Lunimosity = 2238.72
# Effective Temperature = 5800
# X = 0.746
# Z = 0.004




import matplotlib.pyplot as plt
import mesa_reader as mr

h=mr.MesaData('/mnt/sda1/mesa-r24.03.1/star/test_suite/rsp_Cepheid_5/LOGS/history.data')
plt.plot(h.num_periods,h.growth)
plt.xlabel("Pulsation Cycle")
plt.ylabel("Growth")
plt.title("Growth vs Pulsation Cycle (5-days)")
plt.show()

# %%
# Input Parameters : 
# Mass = 5.1
# Lunimosity = 3006.08
# Effective Temperature = 5396
# X = 0.7
# Z = 0.02




import matplotlib.pyplot as plt
import mesa_reader as mr

h=mr.MesaData('/mnt/sda1/mesa-r24.03.1/star/test_suite/rsp_Cepheid_10/LOGS/history.data')
plt.plot(h.num_periods,h.growth)
plt.xlabel("Pulsation Cycle")
plt.ylabel("Growth")
plt.title("Growth vs Pulsation Cycle (10-days)")
plt.show()

# %%
# Input Parameters : 
# Mass = 7.7
# Lunimosity = 4965.92
# Effective Temperature = 5332
# X = 0.7
# Z = 0.02


import matplotlib.pyplot as plt
import mesa_reader as mr

h=mr.MesaData('/mnt/sda1/mesa-r24.03.1/star/test_suite/rsp_Cepheid_12/LOGS/history.data')
plt.plot(h.num_periods,h.growth)
plt.xlabel("Pulsation Cycle")
plt.ylabel("Growth")
plt.title("Growth vs Pulsation Cycle (12-days)")
plt.show()

# %% [markdown]
# ## Luminosity vs Pulsation Cycle

# %%
# Input Parameters : 
# Mass = 5.4
# Lunimosity = 2238.72
# Effective Temperature = 5800
# X = 0.746
# Z = 0.004



import matplotlib.pyplot as plt
import mesa_reader as mr

h=mr.MesaData('/mnt/sda1/mesa-r24.03.1/star/test_suite/rsp_Cepheid_5/LOGS/history.data')
plt.plot(h.num_periods,h.log_L)
plt.xlabel("Pulsation Cycle")
plt.ylabel("log L")
plt.title("log L vs Pulsation Cycle (5-days)")
plt.show()

# %%
# Input Parameters : 
# Mass = 5.1
# Lunimosity = 3006.08
# Effective Temperature = 5396
# X = 0.7
# Z = 0.02



import matplotlib.pyplot as plt
import mesa_reader as mr

h=mr.MesaData('/mnt/sda1/mesa-r24.03.1/star/test_suite/rsp_Cepheid_10/LOGS/history.data')
plt.plot(h.num_periods,h.log_L)
plt.xlabel("Pulsation Cycle")
plt.ylabel("log L")
plt.title("log L vs Pulsation Cycle (10-days)")
plt.show()

# %%
# Input Parameters : 
# Mass = 7.7
# Lunimosity = 4965.92
# Effective Temperature = 5332
# X = 0.7
# Z = 0.02


import matplotlib.pyplot as plt
import mesa_reader as mr

h=mr.MesaData('/mnt/sda1/mesa-r24.03.1/star/test_suite/rsp_Cepheid_12/LOGS/history.data')
plt.plot(h.num_periods,h.log_L)
plt.xlabel("Pulsation Cycle")
plt.ylabel("log L")
plt.title("log L vs Pulsation Cycle (12-days)")
plt.show()
